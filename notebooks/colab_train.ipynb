# %% [markdown]
# # How to Train Your GPT : Run in Colab
#
# This notebook clones the repo, installs dependencies and trains
# a tiny GPT model on Wikipedia text. It takes about 5 minutes on
# the free Colab GPU. At the end you will have a trained model
# that can generate text.
#
# Click **Runtime → Run all** to go from zero to a working language
# model in one click.

# %% [markdown]
# ## Step 1: Clone the repo

# %%
# !git clone https://github.com/ultimateBroK/how-to-train-your-gpt.git

# %% [markdown]
# ## Step 2: Install dependencies

# %%
# %cd how-to-train-your-gpt
# !pip install -q tiktoken datasets matplotlib

# %% [markdown]
# ## Step 3: Verify GPU

# %%
import torch
print(f"PyTorch {torch.__version__}")
if torch.cuda.is_available():
    print(f"GPU: {torch.cuda.get_device_name(0)}")
    print(f"Memory: {torch.cuda.get_device_properties(0).total_mem / 1e9:.1f} GB")
else:
    print("No GPU found. Training will be slow.")

# %% [markdown]
# ## Step 4: Train the model
#
# This trains for 500 steps with a tiny model (d_model=256, 4 layers).
# It takes about 2-5 minutes on a T4 GPU. For a bigger model edit
# the config in main.py and uncomment the GPT-2 Small config.

# %%
# %run main.py

# %% [markdown]
# ## Step 5: Show the loss curve

# %%
import os
from IPython.display import Image, display
if os.path.exists('loss_curve.png'):
    display(Image('loss_curve.png'))
else:
    print('No loss curve found. Training may have failed.')

# %% [markdown]
# ## Done
#
# You just trained a language model from scratch on Wikipedia text.
# The checkpoint is saved at `checkpoints/model.pt`. To generate
# text open the inference notebook at `notebooks/09_inference.ipynb`.
